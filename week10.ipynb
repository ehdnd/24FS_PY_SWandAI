# %%
import matplotlib.pyplot as plt

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994)
plt.plot(temp2018)

plt.show()

# %%
import matplotlib.pyplot as plt

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994")
plt.plot(temp2018, label="2018")

plt.show()

# %%
import matplotlib.pyplot as plt

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994", marker="v")
plt.plot(temp2018, label="2018", marker="s")

plt.show()

# %%
import matplotlib.pyplot as plt

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994", marker="v")
plt.plot(temp2018, label="2018", marker="s")

plt.ylim(20, 45)

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994", marker="v")
plt.plot(temp2018, label="2018", marker="s")

plt.xlim(0, 9)
plt.ylim(20, 45)

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994", marker="v")
plt.plot(temp2018, label="2018", marker="s")

plt.ylim(20, 45)

plt.legend()
plt.title("temperature")
plt.show()

# %%
import matplotlib.pyplot as plt

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994", marker="v")
plt.plot(temp2018, label="2018", marker="s")

plt.ylim(20, 45)
plt.legend()

plt.rc("font", family="AppleGothic")
plt.title("최고 기온 비교")

plt.show()

# %%
import matplotlib.pyplot as plt

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994", marker="v")
plt.plot(temp2018, label="2018", marker="s")

plt.ylim(20, 45)
plt.legend()

plt.rc("font", family="AppleGothic")
plt.title("최고 기온 비교")

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994", marker="v")
plt.plot(temp2018, label="2018", marker="s")

plt.ylim(20, 45)
plt.legend()

plt.rc("font", family="AppleGothic")
plt.title("최고 기온 비교")
plt.grid(True)
plt.xlabel("날짜 변화")
plt.ylabel("최고 기온")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994", marker="v")
plt.plot(temp2018, label="2018", marker="s")

plt.ylim(20, 45)
plt.legend()

plt.rc("font", family="AppleGothic")
plt.title("최고 기온 비교")
plt.grid(True)
plt.xlabel("날짜 변화")
plt.ylabel("최고 기온")

plt.xticks(
    np.arange(10),
    ("1일", "2일", "3일", "4일", "5일", "6일", "7일", "8일", "9일", "10일"),
)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

templ994 = [39.6, 37.9, 37.9, 34.9, 33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4, 35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

plt.plot(templ994, label="1994", marker="v")
plt.plot(temp2018, label="2018", marker="s")

plt.ylim(20, 45)
plt.legend()

plt.rc("font", family="AppleGothic")
plt.title("최고 기온 비교")
plt.grid(True)
plt.xlabel("날짜 변화")
plt.ylabel("최고 기온")

plt.xticks(
    np.arange(10),
    ("1일", "2일", "3일", "4일", "5일", "6일", "7일", "8일", "9일", "10일"),
)
plt.yticks(np.arange(25, 42, 2))

plt.show()
